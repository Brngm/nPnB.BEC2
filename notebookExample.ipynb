# %% [markdown]
# ## notebookExample.ipynb

# %% [markdown]
# ## notebookExample for nPnB-QUICK-BEC
#         December 2025
#         Bruno Gaume <bruno.gaume@iscpif.fr>
# ## Reference:
#     nPnB framework Reference:
#         Two antagonistic objectives for one multi-scale graph clustering framework,
#         Bruno Gaume, Ixandra Achitouv, David Chavalarias Nature Scientific Reports (2025)
#         https://www.nature.com/articles/s41598-025-90454-w
#
#     BEC2 Algorithm Reference:
#         BEC.2: A fast and relevant Multi-Scale Graph Clustering algorithm in nPnB framework,
#         Bruno Gaume (2025)
#         https://hal.science/hal-05053057v1
#
# ## Before clic on [Kernel]-->[Restart Kernel and Run All Ceels ...]
#     We have to compile nPnB-QUICK-BEC_C++/nPnB-QUICK-BEC.cpp (see nPnB-QUICK-BEC/ReadMe.txt)
#
# ## nPnB-QUICK-BEC
#     nPnB-QUICK-BEC(G, sp, so) is a kind of telescope for observing the graph G modeling a complex system
#     where nodes represent the basic lowest-level entities and edges represent their interactions.
#
#     sp defines the desired scale of description of the modules as highest-level entities
#     and so the level of overlap of these entities.
#
#     INPUTS:
#         sp and so in [0,1] and Epsilon in [0,1[
#
#         The smaller sp, the finer the scale of description, producing many small, dense modules.
#         The larger sp, the coarser the scale of description, producing fewer, larger, less dense modules.
#
#         The smaller Epsilon, the more we favor quality.
#         The larger Epsilon, the more we favor computation speed (at the expense of quality).
#         Epsilon=0.01 is a good compromise between speed and quality.
#
#     LINKS:
#         nPnB-QUICK-BEC can work on graphs with multiple directed or undirected edges.
#         For example, [... ((4,7), 2), ((4,7), 0.5), ((7,4), 10), ...] is equivalent to [... ((4,7), 12.5), ...]
#         And is counted as a single undirected edge {4,7} of weight 12.5.

# %%
# =============================================================================
# Imports
# =============================================================================
import os
import sys
import subprocess
import json
# -----------------------------------------------------------------------------
beep = lambda x: os.system("echo -n '\a';sleep 0.1;" * x)
here=os.path.abspath(os.getcwd())+"/"
print("here ='%s'"%here)

# =============================================================================
sys.path.append(here+"Graph-Visualization/")
import libraryVisualGraph as Vis
sys.path.append(here+"nPnB-QUICK-BEC/")
import nPnB_QUICK_BEC_Interface as nPnB
# =============================================================================

sys.path
devnull = open(os.devnull, 'w')
sys.stderr=devnull
junk=beep(1) # everything is well loaded
# Out:
# here ='/home/bruno/BG/WORK/WoWo/PISTES/npnb-bec2_Gitlab_ISCPIF/npnb-bec2/nPnBviz.11/'
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=0.000000, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=0.000000)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=37: P=1.000000, R=0.507874, F(Beta=0.000000)=1.000000 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=37: P=1.000000, R=0.507874, F(Beta=0.000000)=1.000000 (0 seconds)
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# Clust.Output: |C|=37, TP=129.000000, TN=2672.000000, FP=0.000000, FN=125.000000
# P=1.000000, R=0.507874, F(Beta=0.000000)=1.000000
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=0.000000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=37
# -->Connex modules in G: |C|=37: (0 seconds)
#    P=1.000000, R=0.507874, F(Beta=0.000000)=1.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=37, TP=170.000000, TN=2672.000000, FP=0.000000, FN=84.000000
# P=1.000000, R=0.669291, F(Beta=0.000000)=1.000000
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=0.414214, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=0.414214)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=35: P=0.985816, R=0.547244, F(Beta=0.414214)=0.882268 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=35: P=0.985816, R=0.547244, F(Beta=0.414214)=0.882268 (0 seconds)
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# Clust.Output: |C|=35, TP=139.000000, TN=2670.000000, FP=2.000000, FN=115.000000
# P=0.985816, R=0.547244, F(Beta=0.414214)=0.882268
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=0.414214
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=35
# -->Connex modules in G: |C|=35: (0 seconds)
#    P=0.985816, R=0.547244, F(Beta=0.414214)=0.882268
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=35, TP=204.000000, TN=2668.000000, FP=4.000000, FN=50.000000
# P=0.980769, R=0.803150, F(Beta=0.414214)=0.950001
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=1.000000, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=1.000000)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=32: P=0.916667, R=0.649606, F(Beta=1.000000)=0.760369 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=32: P=0.916667, R=0.649606, F(Beta=1.000000)=0.760369 (0 seconds)
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# Clust.Output: |C|=32, TP=165.000000, TN=2657.000000, FP=15.000000, FN=89.000000
# P=0.916667, R=0.649606, F(Beta=1.000000)=0.760369
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=1.000000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=32
# -->Connex modules in G: |C|=32: (0 seconds)
#    P=0.916667, R=0.649606, F(Beta=1.000000)=0.760369
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=32, TP=238.000000, TN=2642.000000, FP=30.000000, FN=16.000000
# P=0.888060, R=0.937008, F(Beta=1.000000)=0.911877
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=2.414214, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=2.414214)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=20: P=0.450450, R=0.787402, F(Beta=2.414214)=0.709661 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=17: P=0.422998, R=0.811024, F(Beta=2.414214)=0.714975 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=18: P=0.429769, R=0.807087, F(Beta=2.414214)=0.715139 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=18, TP=205.000000, TN=2400.000000, FP=272.000000, FN=49.000000
# P=0.429769, R=0.807087, F(Beta=2.414214)=0.715139
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=2.414214
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=18
# -->Connex modules in G: |C|=18: (0 seconds)
#    P=0.429769, R=0.807087, F(Beta=2.414214)=0.715139
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=18, TP=249.000000, TN=2338.000000, FP=334.000000, FN=5.000000
# P=0.427101, R=0.980315, F(Beta=2.414214)=0.824010
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=3.077684, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=3.077684)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=21: P=0.396552, R=0.814961, F(Beta=3.077684)=0.740365 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=19: P=0.379496, R=0.830709, F(Beta=3.077684)=0.746009 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=19: P=0.379496, R=0.830709, F(Beta=3.077684)=0.746009 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=19, TP=211.000000, TN=2327.000000, FP=345.000000, FN=43.000000
# P=0.379496, R=0.830709, F(Beta=3.077684)=0.746009
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=3.077684
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=19
# -->Connex modules in G: |C|=19: (0 seconds)
#    P=0.379496, R=0.830709, F(Beta=3.077684)=0.746009
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=19, TP=254.000000, TN=2242.000000, FP=430.000000, FN=0.000000
# P=0.371345, R=1.000000, F(Beta=3.077684)=0.860838
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=4.165300, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=4.165300)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=18: P=0.346341, R=0.838583, F(Beta=4.165300)=0.778300 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=15: P=0.307692, R=0.866142, F(Beta=4.165300)=0.788183 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=15: P=0.307692, R=0.866142, F(Beta=4.165300)=0.788183 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=15, TP=220.000000, TN=2177.000000, FP=495.000000, FN=34.000000
# P=0.307692, R=0.866142, F(Beta=4.165300)=0.788183
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=4.165300
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=15
# -->Connex modules in G: |C|=15: (0 seconds)
#    P=0.307692, R=0.866142, F(Beta=4.165300)=0.788183
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=15, TP=254.000000, TN=2090.000000, FP=582.000000, FN=0.000000
# P=0.303828, R=1.000000, F(Beta=4.165300)=0.888991
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=6.313752, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=6.313752)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=6.313752)=0.829579 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=6: P=0.183450, R=0.925197, F(Beta=6.313752)=0.841894 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=6: P=0.183450, R=0.925197, F(Beta=6.313752)=0.841894 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=6, TP=235.000000, TN=1626.000000, FP=1046.000000, FN=19.000000
# P=0.183450, R=0.925197, F(Beta=6.313752)=0.841894
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=6.313752
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=6
# -->Connex modules in G: |C|=6: (0 seconds)
#    P=0.183450, R=0.925197, F(Beta=6.313752)=0.841894
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=6, TP=254.000000, TN=1509.000000, FP=1163.000000, FN=0.000000
# P=0.179252, R=1.000000, F(Beta=6.313752)=0.899240
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=7.026366, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=7.026366)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=7.026366)=0.840307 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=4: P=0.156658, R=0.944882, F(Beta=7.026366)=0.859069 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=4: P=0.156658, R=0.944882, F(Beta=7.026366)=0.859069 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=4, TP=240.000000, TN=1380.000000, FP=1292.000000, FN=14.000000
# P=0.156658, R=0.944882, F(Beta=7.026366)=0.859069
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=7.026366
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=4
# -->Connex modules in G: |C|=4: (0 seconds)
#    P=0.156658, R=0.944882, F(Beta=7.026366)=0.859069
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=4, TP=254.000000, TN=1256.000000, FP=1416.000000, FN=0.000000
# P=0.152096, R=1.000000, F(Beta=7.026366)=0.900351
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=7.915815, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=7.915815)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=7.915815)=0.850172 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=3: P=0.117592, R=0.984252, F(Beta=7.915815)=0.882126 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=3: P=0.117592, R=0.984252, F(Beta=7.915815)=0.882126 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=3, TP=250.000000, TN=796.000000, FP=1876.000000, FN=4.000000
# P=0.117592, R=0.984252, F(Beta=7.915815)=0.882126
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=7.915815
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=3
# -->Connex modules in G: |C|=3: (0 seconds)
#    P=0.117592, R=0.984252, F(Beta=7.915815)=0.882126
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=3, TP=254.000000, TN=788.000000, FP=1884.000000, FN=0.000000
# P=0.118803, R=1.000000, F(Beta=7.915815)=0.895645
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=9.057887, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=9.057887)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=9.057887)=0.859096 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=3: P=0.117592, R=0.984252, F(Beta=9.057887)=0.904022 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=3: P=0.117592, R=0.984252, F(Beta=9.057887)=0.904022 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=3, TP=250.000000, TN=796.000000, FP=1876.000000, FN=4.000000
# P=0.117592, R=0.984252, F(Beta=9.057887)=0.904022
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=9.057887
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=3
# -->Connex modules in G: |C|=3: (0 seconds)
#    P=0.117592, R=0.984252, F(Beta=9.057887)=0.904022
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=3, TP=254.000000, TN=788.000000, FP=1884.000000, FN=0.000000
# P=0.118803, R=1.000000, F(Beta=9.057887)=0.918007
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=10.578895, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=10.578895)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=10.578895)=0.867000 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=3: P=0.117592, R=0.984252, F(Beta=10.578895)=0.923944 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=3: P=0.117592, R=0.984252, F(Beta=10.578895)=0.923944 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=3, TP=250.000000, TN=796.000000, FP=1876.000000, FN=4.000000
# P=0.117592, R=0.984252, F(Beta=10.578895)=0.923944
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=10.578895
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=3
# -->Connex modules in G: |C|=3: (0 seconds)
#    P=0.117592, R=0.984252, F(Beta=10.578895)=0.923944
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=3, TP=254.000000, TN=788.000000, FP=1884.000000, FN=0.000000
# P=0.118803, R=1.000000, F(Beta=10.578895)=0.938359
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=12.706205, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=12.706205)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=12.706205)=0.873817 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=12.706205)=0.942461 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=12.706205)=0.942461 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=251.000000, TN=667.000000, FP=2005.000000, FN=3.000000
# P=0.111259, R=0.988189, F(Beta=12.706205)=0.942461
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=12.706205
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=2
# -->Connex modules in G: |C|=2: (0 seconds)
#    P=0.111259, R=0.988189, F(Beta=12.706205)=0.942461
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=254.000000, TN=660.000000, FP=2012.000000, FN=0.000000
# P=0.112092, R=1.000000, F(Beta=12.706205)=0.953505
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=15.894545, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=15.894545)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=15.894545)=0.879484 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=15.894545)=0.958406 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=15.894545)=0.958406 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=251.000000, TN=667.000000, FP=2005.000000, FN=3.000000
# P=0.111259, R=0.988189, F(Beta=15.894545)=0.958406
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=15.894545
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=2
# -->Connex modules in G: |C|=2: (0 seconds)
#    P=0.111259, R=0.988189, F(Beta=15.894545)=0.958406
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=254.000000, TN=660.000000, FP=2012.000000, FN=0.000000
# P=0.112092, R=1.000000, F(Beta=15.894545)=0.969715
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=21.204949, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=21.204949)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=21.204949)=0.883949 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=21.204949)=0.971203 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=21.204949)=0.971203 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=251.000000, TN=667.000000, FP=2005.000000, FN=3.000000
# P=0.111259, R=0.988189, F(Beta=21.204949)=0.971203
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=21.204949
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=2
# -->Connex modules in G: |C|=2: (0 seconds)
#    P=0.111259, R=0.988189, F(Beta=21.204949)=0.971203
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=254.000000, TN=660.000000, FP=2012.000000, FN=0.000000
# P=0.112092, R=1.000000, F(Beta=21.204949)=0.982726
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=31.820516, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=31.820516)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=31.820516)=0.887169 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=31.820516)=0.980564 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=31.820516)=0.980564 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=251.000000, TN=667.000000, FP=2005.000000, FN=3.000000
# P=0.111259, R=0.988189, F(Beta=31.820516)=0.980564
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=31.820516
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=2
# -->Connex modules in G: |C|=2: (0 seconds)
#    P=0.111259, R=0.988189, F(Beta=31.820516)=0.980564
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=254.000000, TN=660.000000, FP=2012.000000, FN=0.000000
# P=0.112092, R=1.000000, F(Beta=31.820516)=0.992245
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=63.656741, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=63.656741)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=8: P=0.224429, R=0.889764, F(Beta=63.656741)=0.889113 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=63.656741)=0.986271 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=2: P=0.111259, R=0.988189, F(Beta=63.656741)=0.986271 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=251.000000, TN=667.000000, FP=2005.000000, FN=3.000000
# P=0.111259, R=0.988189, F(Beta=63.656741)=0.986271
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=63.656741
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=2
# -->Connex modules in G: |C|=2: (0 seconds)
#    P=0.111259, R=0.988189, F(Beta=63.656741)=0.986271
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=2, TP=254.000000, TN=660.000000, FP=2012.000000, FN=0.000000
# P=0.112092, R=1.000000, F(Beta=63.656741)=0.998049
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: mmm with: Beta=16331239353195370.000000, Epsilon=0.010000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=77
# -->Connex modules in G: |C|=77: (0 seconds)
#    P=0.000000, R=0.000000, F(Beta=16331239353195370.000000)=0.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# NODES MOVE-->|C|=3: P=0.111366, R=0.956693, F(Beta=16331239353195370.000000)=0.956693 (0 seconds)
# ----------------------------------------------------------------
# MODULES MOVE-->|C|=1: P=0.086808, R=1.000000, F(Beta=16331239353195370.000000)=1.000000 (0 seconds)
# ----------------------------------------------------------------
# NODES MOVE-->|C|=1: P=0.086808, R=1.000000, F(Beta=16331239353195370.000000)=1.000000 (0 seconds)
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=1, TP=254.000000, TN=0.000000, FP=2672.000000, FN=0.000000
# P=0.086808, R=1.000000, F(Beta=16331239353195370.000000)=1.000000
# OVERALL TIME: 0.000000 seconds
# ================================================================
#
#
# ================================================================
# nPnB-QUICK-BEC: Overlaps with: Beta=16331239353195370.000000
# G:77 vertices, 254 edges, 1.000000 = mean edges weight
# Clust.Input |C0|=1
# -->Connex modules in G: |C|=1: (0 seconds)
#    P=0.086808, R=1.000000, F(Beta=16331239353195370.000000)=1.000000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
# Clust.Output: |C|=1, TP=254.000000, TN=0.000000, FP=2672.000000, FN=0.000000
# P=0.086808, R=1.000000, F(Beta=16331239353195370.000000)=1.000000
# OVERALL TIME: 0.000000 seconds
# ================================================================

# %% [markdown]
# # ACTION

# %%
# VISUALIZATION OF CLUSTERIZED TERRAIN GRAPHS
if True: # activate the cell
    
    # INPUTS @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    # TERRAIN GRAPH
    namegraph = "miserables"
    # INPUT: string
    # "automate_de_tesselation"
    # "zachary-karate-club"
    # "causer"
    # "jouer"
    # "miserables"
    # "GoodGraph"
    # "community-detection"
    # "e-mail"
    # "DicoSynVerbe"
    # ====================================================================
    # BROWSER
    browser="google-chrome"; # INPUT: string 'firefox' or 'google-chrome'
    # ====================================================================
    # DESCRIPTION SCALES: list of float in [0,1] (scales of description)
    S=[0.0, 0.25, 0.50, 0.75, 0.80, 0.85, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1]; 
    #S=[0.95] # one might prefer a single scale of description

    # EPSILON: float in [0,1[ (default 0.01)
    Epsilon=0.01;
    # @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    
    # LOAD GRAPH
    with open("./Graph-Json/%s.json"%(namegraph), "r") as f: graph = json.load(f)
    
    # COMPUTE CLUSTERINGS
    nbv=len(graph["nodes"])
    description_scales=[]
    scoreP=[]
    scoreO=[]
    member=[[] for _ in range(nbv)]
    Sname=""
    for k in range(len(S)):
        description_scales.append(S[k])
        Sname=Sname+("%s-"%str(S[k]) if k<(len(S)-1)  else "%s"%(str(S[k])))

        #-----------------------------------------------------------------------------------------
        # Compute Cp, the clustering by partition
        Cp, P, R, F1, Fs, TP, TN, FP, FN, timep = nPnB.nPnB_mmm(graph, sp=S[k],
                            C0string=False, RandNode=False, Epsilon=Epsilon, Verbose=False);
        print("Partitional clustering (sp=%.2f) computed in %.2f s"%(S[k], timep))
        #-----------------------------------------------------------------------------------------
        
        scoreP_k='"|Cp|=%i: P=%.2f, R=%.2f, F0.50=%.2f, F%s=%.2f"'%(len(Cp),P,R,F1,str(S[k]),Fs)
        scoreP.append(scoreP_k)
        Cp.sort(key = lambda z : len(z), reverse=True)

        #-----------------------------------------------------------------------------------------
        # Compute Cpo the clustering with overlaps from the clustering by partition Cp
        C0string=nPnB.clust2string(Cp);
        Cpo, Wno, Po, Ro, F1o, Fso, TPo, TNo, FPo, FNo, timeo = nPnB.nPnB_overlaps(graph, so=S[k],
                                                C0string=C0string, RandNode=False, Verbose=True);
        Co=[Cpo[i]+Wno[i] for i in range(len(Cpo))]
        print("Overlaping  clustering (sp=%.2f, so=%.2f) computed in %.2f s\n"%(S[k],S[k],timeo))
        #-----------------------------------------------------------------------------------------

        scoreO_k='"|Co|=%i: P=%.2f, R=%.2f, F0.50=%.2f, F%s=%.2f"'%(len(Co),Po,Ro,F1o,str(S[k]),Fso)
        scoreO.append(scoreO_k)

        memberk=[[] for _ in range(nbv)]
        for i in range(len(Cpo)):
            for j in Cpo[i]:
                memberk[j].append(i)

        for i in range(len(Wno)):
            for j in Wno[i]:
                memberk[j].append(i)
                
        for i in range(nbv):
            member[i].append(memberk[i])
    
    # BUILD THE HTML PAGE    
    title="%s: |V|=%i, |E|=%i"%(graph["name"], len(graph["nodes"]), len(graph["links"]))
    HTML_PAGE=Vis.make3DHTML(graph, member, description_scales, scoreP, scoreO, title)

    # SAVE THE HTML PAGE
    namesave="viz3D_%s_S=%s.html"%(graph["name"],Sname)
    path="Graph-Visualization/VISU-HTML/"+namesave
    Vis.saveChemCH(path, HTML_PAGE)

    # DISPLAY THE HTML PAGE
    file_path = os.path.join(here, path)
    process=subprocess.Popen([browser, f'file://{file_path}']) # launch the visualization
    junk=beep(1); print("OK")
# Out:
# Partitional clustering (sp=0.00) computed in 0.00 s
# Overlaping  clustering (sp=0.00, so=0.00) computed in 0.00 s
#
# Partitional clustering (sp=0.25) computed in 0.00 s
# Overlaping  clustering (sp=0.25, so=0.25) computed in 0.00 s
#
# Partitional clustering (sp=0.50) computed in 0.00 s
# Overlaping  clustering (sp=0.50, so=0.50) computed in 0.00 s
#
# Partitional clustering (sp=0.75) computed in 0.00 s
# Overlaping  clustering (sp=0.75, so=0.75) computed in 0.00 s
#
# Partitional clustering (sp=0.80) computed in 0.00 s
# Overlaping  clustering (sp=0.80, so=0.80) computed in 0.00 s
#
# Partitional clustering (sp=0.85) computed in 0.00 s
# Overlaping  clustering (sp=0.85, so=0.85) computed in 0.00 s
#
# Partitional clustering (sp=0.90) computed in 0.00 s
# Overlaping  clustering (sp=0.90, so=0.90) computed in 0.00 s
#
# Partitional clustering (sp=0.91) computed in 0.00 s
# Overlaping  clustering (sp=0.91, so=0.91) computed in 0.00 s
#
# Partitional clustering (sp=0.92) computed in 0.00 s
# Overlaping  clustering (sp=0.92, so=0.92) computed in 0.00 s
#
# Partitional clustering (sp=0.93) computed in 0.00 s
# Overlaping  clustering (sp=0.93, so=0.93) computed in 0.00 s
#
# Partitional clustering (sp=0.94) computed in 0.00 s
# Overlaping  clustering (sp=0.94, so=0.94) computed in 0.00 s
#
# Partitional clustering (sp=0.95) computed in 0.00 s
# Overlaping  clustering (sp=0.95, so=0.95) computed in 0.00 s
#
# Partitional clustering (sp=0.96) computed in 0.00 s
# Overlaping  clustering (sp=0.96, so=0.96) computed in 0.00 s
#
# Partitional clustering (sp=0.97) computed in 0.00 s
# Overlaping  clustering (sp=0.97, so=0.97) computed in 0.00 s
#
# Partitional clustering (sp=0.98) computed in 0.00 s
# Overlaping  clustering (sp=0.98, so=0.98) computed in 0.00 s
#
# Partitional clustering (sp=0.99) computed in 0.00 s
# Overlaping  clustering (sp=0.99, so=0.99) computed in 0.00 s
#
# Partitional clustering (sp=1.00) computed in 0.00 s
# Overlaping  clustering (sp=1.00, so=1.00) computed in 0.00 s
#
# Ouverture dans une session de navigateur existante.
# OK

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@@
