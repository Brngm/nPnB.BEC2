# %% [markdown]
# ## notebook_visualization.ipynb

# %%
# =============================================================================
# Imports
# =============================================================================
import os
import sys
import subprocess
# -----------------------------------------------------------------------------
beep = lambda x: os.system("echo -n '\a';sleep 0.1;" * x)
here=os.path.abspath(os.getcwd())+"/"
print("here ='%s'"%here)

# =============================================================================
sys.path.append(here+"Graph-Visualization/")
import libraryVisualGraph as Vis

sys.path.append(here+"nPnB/")
import nPnBinterface as nPnB
import GraphFormatConverter as GFC
# =============================================================================

sys.path
devnull = open(os.devnull, 'w')
sys.stderr=devnull
junk=beep(1) # everything is well loaded

# %% [markdown]
# # ACTION ACTION ACTION ACTION ACTION ACTION ACTION

# %%
# Visualize graph in html
if True:
    # @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    # INPUT: Choose the graph, the description scales and the browser
    nameGraph="miserables.nPnB.txt"
    My_scales=[0.5] # your own description scales
    IS=True # Intrinsic Scales
    browser="google-chrome"; # 'firefox' or 'google-chrome' or ...
    # -------------------------------------------
    Epsilon=0.01; # in [0,1]
    step=0.001; # in [0,1]
    eqon="equal"; # "equal" or "len"
    # @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    
    InfileGraph="data/%s"%(nameGraph)

    # Computes clusterings at different scales of description in C
    C=[]
    if IS:
        C = nPnB.clust_intrinsic(InfileGraph, Epsilon=Epsilon, step=step, eqon=eqon)
        print("%s intrinsic scales"%(len(C)))
    SI = [c["input_sp"] for c in C]
    C = C+nPnB.clust_scale(InfileGraph, [s for s in My_scales if not s in SI])

    # Builds the html page
    gjson=GFC.GRAPH_nPnB_2_json(InfileGraph)
    path="Graph-Visualization/VISU-HTML/"+nameGraph+"_Vis.HTML"
    Vis.make3DHTML(gjson, C, path)
    
    # Display the html page
    file_path = os.path.join(here, path)
    process=subprocess.Popen([browser, f'file://{file_path}']) # launch the visualization
    junk=beep(1); print("OK")

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@@
